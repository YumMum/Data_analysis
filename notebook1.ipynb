# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
obj = pd.Series([1, -2, 3, -4])
print(obj)
# Out:
# 0    1
# 1   -2
# 2    3
# 3   -4
# dtype: int64

# %%
data = {
    'name': ['John', 'Doe', 'Jim', 'Jike', 'Jom'],
    'age': [20, 21, 22, 23, 24],
    'score': [80, 90, 80, 90, 80],
    'sex': ['M', 'F', 'M', 'F', 'M']
}
df = pd.DataFrame(data,index=['1','2','3','4','5'])
print(df)
# Out:
#    name  age  score sex
# 1  John   20     80   M
# 2   Doe   21     90   F
# 3   Jim   22     80   M
# 4  Jike   23     90   F
# 5   Jom   24     80   M

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
# ax2 = fig.add_subplot(2,2,2)
ax1.plot([1.5,
          2,
          3.5,
          -1,
          1.6])

# %%
import numpy as np
fig,axes = plt.subplots(2,2,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.random(500),bins=50,color='k',alpha=0.5)
plt.subplots_adjust(wspace=0.1,hspace=0.1)
plt.savefig('test.png')
# print(plt.matplotlib.matplotlib_fname())

# %%
import numpy as np
arr=np.array([[1,1,1],[3,3,3]])
print(arr.ndim)
print(arr.shape)
print(arr.size)
print(arr.dtype)
import numpy as np
A=np.linspace(1,10,4)
print(A)
import numpy as np
A=np.arange(1,10,4)
print(A)
import numpy as np
arr1=np.ones((2,2))
arr2=np.eye(2)
print(arr1+arr2)
import numpy as np
arr1=np.random.randint(1,10,(2,3))
print(arr1<10)
import numpy as np
a=np.array([1,2,3,4,5,6])
b=a.reshape((2,3))
print(b)
# Out:
# 2
# (2, 3)
# 6
# int32
# [ 1.  4.  7. 10.]
# [1 5 9]
# [[2. 1.]
#  [1. 2.]]
# [[ True  True  True]
#  [ True  True  True]]
# [[1 2 3]
#  [4 5 6]]

# %%
import pandas as pd

# 列表[[1,2,3],[4,5,6]]创建df1对象
df1 = pd.DataFrame([[1, 2, 3], [4, 5, 6]])
# 列表[[2,4,6],[7,8,9]]创建df2对象
df2 = pd.DataFrame([[2, 4, 6], [7, 8, 9]])
# 列表[[1,2],[3,4]]创建df3对象
df3 = pd.DataFrame([[1, 2], [3, 4]])

# df1加df2
add_result = df1 + df2
print("加运算:",add_result)
# df1乘df3
mul_result = df1 * df3
print("乘运算:")
print(mul_result)

# df1乘df3，缺失值为0
mul_result_fillna = (df1 * df3).fillna(0)
print("乘运算:")
print(mul_result_fillna)
# Out:
# 加运算:     0   1   2
# 0   3   6   9
# 1  11  13  15
# 乘运算:
#     0   1   2
# 0   1   4 NaN
# 1  12  20 NaN
# 乘运算:
#     0   1    2
# 0   1   4  0.0
# 1  12  20  0.0

# %%
import matplotlib.pyplot as plt
import numpy as np

# 创建一个包含 2 行 2 列子图的 Figure 对象
fig, axes = plt.subplots(2, 2)

# 生成一些数据
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = np.exp(x)

# 在第一个子图上绘制正弦曲线
axes[0, 0].plot(x, y1)
axes[0, 0].set_title('Sine')

# 在第二个子图上绘制余弦曲线
axes[0, 1].plot(x, y2)
axes[0, 1].set_title('Cosine')

# 在第三个子图上绘制正切曲线
axes[1, 0].plot(x, y3)
axes[1, 0].set_title('Tangent')

# 在第四个子图上绘制指数曲线
axes[1, 1].plot(x, y4)
axes[1, 1].set_title('Exponential')

# 调整子图之间的间距
plt.tight_layout()

# 显示图形
plt.show()

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# 加载鸢尾花数据集
iris = datasets.load_iris()
X = iris.data  # 特征
y = iris.target  # 标签

# 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

# 创建SVM分类器
clf = SVC()

# 训练模型
clf.fit(X_train, y_train)

# 进行预测
y_pred = clf.predict(X_test)

# 计算准确率
accuracy = accuracy_score(y_test, y_pred)
print(f"模型准确率: {accuracy:.2f}")
# Out:
# 模型准确率: 1.00
